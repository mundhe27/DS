# %% [raw]
# # Perform the following operations using ‘python’ Language on the Amazon
# book review Data set.
# 1) Create data subsets(Row wise)
# 2) Merge Data (Row wise)
# 3) Sort Data
# 4) Transposing Data
# 5) Reshape Data

# %%
import pandas as pd
import numpy as np 
df = pd.read_csv(r"C:\Users\yasha\Desktop\Ashish\sem 6\DSBDA\DSBDA Lab Datasets\Amazonbookreviews.csv")
df.head()
# Out:
#        reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# ...

# %%
#creating the subset1

df1 = df[['asin','helpful','overallRating']].loc[0:15]
df1
# Out:
#         asin  helpful  overallRating
# 0    23456.0        2            4.0
# 1   879877.0        3            3.0
# 2    23456.0        3            2.5
# 3    67578.0        3            2.2
# 4      123.0        3            3.0
# 5   236789.0        3            3.0
# 6        NaN        3            3.0
# 7   224442.0        3            3.0
# 8    98767.0        2            3.0
# 9    78761.0        2            5.0
# 10  321456.0        2            4.0
# 11  876231.0        2            4.0
# 12     987.0        2            4.0
# 13     234.0        2            3.0
# 14     124.0        2            3.0
# 15     156.0        2            3.0

# %%
#creating the subset2

df2 = df[['asin','helpful','overallRating']].loc[16:30]
df2
# Out:
#        asin  helpful  overallRating
# 16    876.0        2            3.0
# 17    123.0        2            2.0
# 18    987.0        2            2.0
# 19  22456.0        2            2.0
# 20   9876.0        2            2.0
# 21   3451.0        2            4.0
# 22    879.0        2            4.0
# 23    321.0        2            4.0
# 24      2.0        3            4.0
# 25      1.0        3            4.0
# 26     23.0        3            4.0
# 27     11.0        3            4.0
# 28     11.0        3            4.0
# 29     23.0        3            4.0
# 30  21221.0        3            4.0

# %%
#creating the subset3

df3 = df[['asin','helpful','overallRating']].loc[31:44]
df3
# Out:
#        asin  helpful  overallRating
# 31     21.0        3            4.0
# 32  12212.0        3            3.0
# 33   2121.0        3            3.0
# 34  21212.0        3            3.0
# 35  21221.0        3            3.0
# 36  22245.0        3            2.0
# 37    678.0        3            2.0
# 38    111.0        3            2.0
# 39    223.0        3            2.0
# 40   2312.0        3            4.0
# 41   1222.0        2            4.0
# 42  11111.0        2            4.0
# 43   9800.0        2            4.0
# 44      NaN        2            4.0

# %%
#merge 
merging = pd.concat([df1,df2,df3])
merging
# Out:
#         asin  helpful  overallRating
# 0    23456.0        2            4.0
# 1   879877.0        3            3.0
# 2    23456.0        3            2.5
# 3    67578.0        3            2.2
# 4      123.0        3            3.0
# 5   236789.0        3            3.0
# 6        NaN        3            3.0
# 7   224442.0        3            3.0
# 8    98767.0        2            3.0
# 9    78761.0        2            5.0
# 10  321456.0        2            4.0
# 11  876231.0        2            4.0
# 12     987.0        2            4.0
# 13     234.0        2            3.0
# 14     124.0        2            3.0
# 15     156.0        2            3.0
# 16     876.0        2            3.0
# 17     123.0        2            2.0
# 18     987.0        2            2.0
# 19   22456.0        2            2.0
# 20    9876.0        2            2.0
# 21    3451.0        2            4.0
# 22     879.0        2            4.0
# 23     321.0        2            4.0
# ...

# %%
#sort 
sort_values=df.sort_values('overallRating',ascending=False)
sort_values
# Out:
#          reviewerID      asin reviewername  helpful  \
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 21   NIKI12NIKI1231    3451.0       SHREYA        2
# 43      123LKIUHNFG    9800.0         MAHI        2
# 42       QWCVFED123   11111.0        DHONI        2
# 41        ASWER1234    1222.0       PREETI        2
# 40      67FDASAA123    2312.0      NANAJJI        3
# 31   1234ZSDFREQWEG      21.0       VARSHA        3
# 30    MNHJ879WERFGH   21221.0         JOHN        3
# 29  ASDF345671QWERT      23.0        HARRY        3
# 28  CADERVG3450EREW      11.0       MORRIS        3
# 27  BA2345WERSDFRER      11.0        CHRIS        3
# 26     GHAU8768QWER      23.0       MARYLS        3
# 25   MIKISDF1232XAD       1.0        JACOB        3
# 24   NIKI12NIKI1231       2.0      PRAJWAL        3
# 23     GHAU8768QWER     321.0       SUMEET        2
# 22   MIKISDF1232XAD     879.0    AISHWARYA        2
# ...

# %%
#transpose
df.transpose()
# Out:
#                                                                0   \
# reviewerID                                         A2SUAM1J3GNN3B
# asin                                                      23456.0
# reviewername                                                SNEHA
# helpful                                                         2
# reviewerText    I bought this for my husband who plays the pia...
# overallRating                                                 4.0
# Summary                                               SUBWAY SURF
# UnixreviewTime                                                NaN
# reviewTime                                                    NaN
#
#                                1                2                3   \
# reviewerID         A2SUAN1J3GNN0C   A2SUAN1J3GNN7B   A5SUAN1J3GNN9B
# asin                     879877.0          23456.0          67578.0
# reviewername              KARTHII         SHASHANK            NITIN
# ...

# %%
df.shape
# Out:
# (45, 9)

# %%
#reshape
pivot_table = pd.pivot_table(df,index=['helpful','overallRating'], values='asin')
pivot_table
# Out:
#                              asin
# helpful overallRating
# 2       2.0              8360.500
#         3.0             20031.400
#         4.0            124891.400
#         5.0             78761.000
# 3       2.0              5814.250
#         2.2             67578.000
#         2.5             23456.000
#         3.0            174749.625
#         4.0              2625.000

# %%
# merge another way
data1 = {'id':['1','2','3','4'],
         'name':['ashish','ramesh','banty','munna'],
         'subj':['maths','chem','phy','bio']}

data2 = {'id':['1','5','3','7'],
         'address':['dange','chnichwad','pune','mumbai'],
         'color':['red','green','blue','yellow']}

#converting dictionary to dataframe
demo1=pd.DataFrame(data1)

#converting dictionaries to dataframe
demo2=pd.DataFrame(data2)

data = pd.merge(demo1,demo2, on='id')
data
# Out:
#   id    name   subj address color
# 0  1  ashish  maths   dange   red
# 1  3   banty    phy    pune  blue
